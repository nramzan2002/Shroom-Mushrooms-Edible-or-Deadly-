# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('mushrooms.csv')

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
df.shape
# Out:
# (8124, 23)

# %%
df.dtypes
# Out:
# class                       object
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# dtype: object

# %%
df.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# ...

# %%
#Data Pre-Processing and Cleaning

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8124, step=1)

# %%
df = df.drop(['gill-attachment', 'stalk-surface-below-ring', 'stalk-surface-above-ring', 'stalk-color-below-ring', 'veil-type', 'veil-color','ring-number','ring-type'], axis =1)

# %%
df.shape
# Out:
# (8124, 15)

# %%
df.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-spacing  \
# count   8124      8124        8124      8124    8124  8124         8124
# unique     2         6           4        10       2     9            2
# top        e         x           y         n       f     n            c
# freq    4208      3656        3244      2284    4748  3528         6812
#
#        gill-size gill-color stalk-shape stalk-root stalk-color-above-ring  \
# count       8124       8124        8124       8124                   8124
# unique         2         12           2          5                      9
# top            b          b           t          b                      w
# freq        5612       1728        4608       3776                   4464
#
#        spore-print-color population habitat
# count               8124       8124    8124
# unique                 9          6       7
# top                    w          v       d
# freq                2388       4040    3148

# %%
df = df.sample(n=5000, random_state=42).reset_index(drop=True)

# %%
df.shape
# Out:
# (5000, 15)

# %%
df.isnull().sum()
# Out:
# class                     0
# cap-shape                 0
# cap-surface               0
# cap-color                 0
# bruises                   0
# odor                      0
# gill-spacing              0
# gill-size                 0
# gill-color                0
# stalk-shape               0
# stalk-root                0
# stalk-color-above-ring    0
# spore-print-color         0
# population                0
# habitat                   0
# dtype: int64

# %%
##Modeling 
from sklearn import tree

# %%
X = df.drop(columns = ['class'])
y = df['class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
X_train_encoded = pd.get_dummies(X_train)
X_test_encoded = pd.get_dummies(X_test)
X_test_encoded = X_test_encoded.reindex(columns=X_train_encoded.columns, fill_value=0)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((4000, 14), (1000, 14), (4000,), (1000,))

# %%
clf = tree.DecisionTreeClassifier(random_state = 42)

# %%
clf.fit(X_train_encoded, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
predicted = clf.predict(X_test_encoded)

# %%
predicted
# Out:
# array(['p', 'p', 'e', 'e', 'p', 'e', 'p', 'e', 'e', 'e', 'p', 'p', 'p',
#        'p', 'e', 'e', 'p', 'e', 'e', 'e', 'p', 'p', 'p', 'p', 'e', 'e',
#        'p', 'p', 'p', 'e', 'p', 'p', 'p', 'e', 'e', 'e', 'p', 'e', 'e',
#        'p', 'p', 'p', 'e', 'e', 'e', 'p', 'p', 'p', 'p', 'e', 'p', 'p',
#        'e', 'p', 'e', 'e', 'p', 'p', 'e', 'e', 'e', 'e', 'p', 'p', 'e',
#        'p', 'e', 'p', 'p', 'e', 'e', 'p', 'e', 'p', 'p', 'e', 'p', 'p',
#        'p', 'p', 'e', 'e', 'e', 'p', 'p', 'p', 'p', 'p', 'p', 'e', 'e',
#        'e', 'e', 'p', 'e', 'e', 'p', 'e', 'e', 'p', 'e', 'p', 'p', 'e',
#        'p', 'p', 'p', 'e', 'e', 'p', 'p', 'e', 'p', 'p', 'p', 'e', 'e',
#        'p', 'p', 'p', 'e', 'e', 'p', 'p', 'e', 'e', 'e', 'e', 'e', 'p',
#        'p', 'e', 'p', 'p', 'p', 'e', 'e', 'e', 'e', 'p', 'p', 'e', 'e',
#        'p', 'e', 'e', 'e', 'p', 'e', 'p', 'p', 'e', 'p', 'p', 'e', 'p',
#        'p', 'p', 'e', 'e', 'p', 'p', 'p', 'e', 'p', 'p', 'p', 'e', 'p',
# ...

# %%
clf.score(X_test_encoded, y_test)
# Out:
# 1.0

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(6, 6), dpi=309)
tree.plot_tree(clf, max_depth=3, filled=True)
plt.show()

# %%
from sklearn.model_selection import cross_validate
from sklearn import metrics
import numpy as np

# %%
X = df.drop(columns = ['class'])
y = df['class']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %%
X_train_encoded = pd.get_dummies(X_train)
X_test_encoded = pd.get_dummies(X_test)
X_test_encoded = X_test_encoded.reindex(columns=X_train_encoded.columns, fill_value=0)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3500, 14), (1500, 14), (3500,), (1500,))

# %%
clf.fit(X_train_encoded, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
clf.score(X_test_encoded, y_test)
# Out:
# 1.0

# %%
from sklearn.preprocessing import LabelEncoder
non_numeric_columns = X.select_dtypes(exclude=['number']).columns
for col in non_numeric_columns:
    # Use label encoding to convert string values to numeric values
    label_encoder = LabelEncoder()
    X[col] = label_encoder.fit_transform(X[col])
cvs = cross_validate(clf, X, y, cv=10, return_estimator=True)

# %%
cvs['estimator']
# Out:
# [DecisionTreeClassifier(random_state=42),
#  DecisionTreeClassifier(random_state=42),
#  DecisionTreeClassifier(random_state=42),
#  DecisionTreeClassifier(random_state=42),
#  DecisionTreeClassifier(random_state=42),
#  DecisionTreeClassifier(random_state=42),
#  DecisionTreeClassifier(random_state=42),
#  DecisionTreeClassifier(random_state=42),
#  DecisionTreeClassifier(random_state=42),
#  DecisionTreeClassifier(random_state=42)]

# %%
fi = []
classification_reports = []
for model in cvs['estimator']:
    fi.append(list(model.feature_importances_))
    
fi_avg = np.mean(fi, axis=0)

# %%
fi_avg
# Out:
# array([0.00000000e+00, 1.54154736e-03, 6.84842866e-03, 1.88819792e-02,
#        9.01460861e-04, 2.22350296e-04, 1.33168510e-01, 3.34505448e-01,
#        2.77976134e-02, 6.29992026e-02, 1.70152555e-02, 2.07845187e-01,
#        1.76117870e-01, 1.21551474e-02])

# %%
fi_avg = pd.Series(fi_avg, index=X.columns).sort_values(ascending=False)

plt.figure(figsize=(12,6))
chart = sns.barplot(x=fi_avg, y=fi_avg.index)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.show()
# Out:
# C:\Users\Noor Ramzan\AppData\Local\Temp\ipykernel_23532\1685784069.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')

# %%
predicted = clf.predict(X_test_encoded)

# %%
print(metrics.classification_report(y_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            e       1.00      1.00      1.00       797
#            p       1.00      1.00      1.00       703
#
#     accuracy                           1.00      1500
#    macro avg       1.00      1.00      1.00      1500
# weighted avg       1.00      1.00      1.00      1500

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, predicted)
# Out:
# array([[797,   0],
#        [  0, 703]], dtype=int64)

# %%
##Model 3 - Pie chart

# %%
edible_count = data['class_e'].sum()
deadly_count = data['class_p'].sum()

# %%
labels = ['Edible', 'Deadly']

# %%
sizes = [edible_count, deadly_count]

# %%
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Percentages of Edible vs. Deadly Mushrooms')
plt.show()

# %%
feature_index = 52
feature_name = X_train_encoded.columns[feature_index]
print("Feature name corresponding to X[52]:", feature_name)
# Out:
# Feature name corresponding to X[52]: stalk-root_r
